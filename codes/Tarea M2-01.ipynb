# %% [markdown]
# # Tarea M2-03: Regresión lineal
#
# Tomando como referencia el ejemplo de la predicción del precio de los viajes en taxi visto durante la clase, analiza el siguiente caso.
#
# En esta ocasión, los datos disponibles contienen, para cada viaje:
#
# - **Distance**. La distancia recorrida por el taxi (en metros).
# - **Time**. La duración del viaje (en segundos).
# - **Type**. El tipo de servicio: 1 para servicio de taxi de sitio y 0 para servicio normal. En el caso del servicio de sitio, el taxi cobra un banderazo mayor porque el taxi se desplaza directamente a la ubicación del cliente (el cliente llama y el taxi va a recogerlo). Por el contrario, en el servicio normal, el banderazo no cambia, ya que el taxi se toma sobre la calle.
# - **Cost**. El costo del viaje (en pesos).

# %% [markdown]
# # Instrucciones
#
# 1. Tomando como referencia el [conjunto de entrenamiento](https://raw.githubusercontent.com/jcobayliss/TC3002B-M2/refs/heads/main/datasets/taxi_ext_train.csv), genera un modelo de regresión lineal que determine el costo del viaje a partir de la distancia recorrida, la duración del viaje y el tipo de servicio.
# 2. Determina, según el modelo de regresión generado, cuál sería el costo del viaje para los casos presentados en el [conjunto de prueba](https://raw.githubusercontent.com/jcobayliss/TC3002B-M2/refs/heads/main/datasets/taxi_ext_test.csv).
# 3. Determina cuál es el error medio cuadrado de la predicción.

# %%
# Cargamos los módulos necesarios.
# COMPLETA EL CODIGO

# %%
# Cargamos los datos de entrenamiento.
# COMPLETA EL CODIGO
# train =

# Separamos los datos de entrenamiento en variables independientes (X) y variable dependiente (y).
# COMPLETA EL CODIGO
# X_train =
# y_train =

# %%
# Cargamos los datos de prueba.
# COMPLETA EL CODIGO
# test =

# Separamos los datos de prueba en variables independientes (X) y variable dependiente (y).
# COMPLETA EL CODIGO
# X_test =
# y_test =

# %%
# Creamos un modelo de regresión lineal.
# COMPLETA EL CODIGO
# model =

# %%
# Entrenamos el modelo.
# COMPLETA EL CODIGO

# %%
# Visualizamos el modelo.
print(model.intercept_, model.coef_)

# %%
# Realizamos la predicción sobre los datos de prueba.
# COMPLETA EL CODIGO
# y_prediction =
print(y_prediction)

# %%
# Visualizamos el error medio cuadrado.
rmse = root_mean_squared_error(y_test, y_prediction)
print(rmse)
