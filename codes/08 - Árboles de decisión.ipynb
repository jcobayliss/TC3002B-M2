# %% [markdown]
# # Árboles de decisión

# %% [markdown]
# ## Ejemplo I
#
# En este ejemplo, usamos un árbol de decisión para clasificar flores, usando el dataset clásico de iris.

# %%
# Importamos los módulos necesarios
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# Leemos los datos que usaremos
iris =  pd.read_csv("https://raw.githubusercontent.com/jcobayliss/TC3002B-M2/refs/heads/main/datasets/iris.csv")

# Separamos las variables independientes de la dependiente
X = iris.drop("Species", axis = 1)
y = iris["Species"]

# Dividimos los datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.60, stratify = y, random_state = 42)

# Creamos un modelo de clasificación usando un árbol de decisión
model = DecisionTreeClassifier(random_state = 42)

# Entrenamos el modelo usando los datos de entrenamiento
model.fit(X_train, y_train)

# Realizamos la predicción usando los datos de prueba
prediction = model.predict(X_test)

# Generamos la matriz de confusión
confusion_matrix(y_test, prediction)
# Out:
# array([[20,  0,  0],
#        [ 0, 19,  1],
#        [ 0,  2, 18]])

# %%
# Importamos los módulos necesarios
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Visualizamos el árbol de decisión generado
plt.figure(figsize=(10, 8))
plot_tree(
    model,
    feature_names = X.columns,
    class_names=[str(c) for c in model.classes_],
    filled = True,
    rounded = True,
    impurity = True,
    proportion = False,
    fontsize = 8
)
# Out:
# [Text(0.4, 0.9166666666666666, 'PetalL <= 2.7\ngini = 0.667\nsamples = 90\nvalue = [30, 30, 30]\nclass = Setosa'),
#  Text(0.3, 0.75, 'gini = 0.0\nsamples = 30\nvalue = [30, 0, 0]\nclass = Setosa'),
#  Text(0.35, 0.8333333333333333, 'True  '),
#  Text(0.5, 0.75, 'PetalL <= 4.95\ngini = 0.5\nsamples = 60\nvalue = [0, 30, 30]\nclass = Versicolor'),
#  Text(0.45, 0.8333333333333333, '  False'),
#  Text(0.2, 0.5833333333333334, 'PetalW <= 1.65\ngini = 0.121\nsamples = 31\nvalue = [0, 29, 2]\nclass = Versicolor'),
#  Text(0.1, 0.4166666666666667, 'gini = 0.0\nsamples = 28\nvalue = [0, 28, 0]\nclass = Versicolor'),
#  Text(0.3, 0.4166666666666667, 'SepalW <= 3.0\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = Virginica'),
#  Text(0.2, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = Virginica'),
#  Text(0.4, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = Versicolor'),
#  Text(0.8, 0.5833333333333334, 'PetalW <= 1.7\ngini = 0.067\nsamples = 29\nvalue = [0, 1, 28]\nclass = Virginica'),
#  Text(0.7, 0.4166666666666667, 'PetalL <= 5.05\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = Virginica'),
#  Text(0.6, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = Virginica'),
#  Text(0.8, 0.25, 'SepalW <= 2.85\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]\nclass = Versicolor'),
#  Text(0.7, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = Versicolor'),
#  Text(0.9, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = Virginica'),
#  Text(0.9, 0.4166666666666667, 'gini = 0.0\nsamples = 26\nvalue = [0, 0, 26]\nclass = Virginica')]

# %% [markdown]
# # Ejemplo II
#
# Generalmente, los árboles de decisión son útiles no sólo por la clasificación en sí, sino porque permiten explicar cómo toman las decisiones. Sin embargo, hay que tener cuidado, porque cambios en el conjunto de entrenamiento pueden cambiar drásticamente la forma del árbol generado.

# %%
# Importamos los módulos necesarios
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# Leemos los datos que usaremos
iris =  pd.read_csv("https://raw.githubusercontent.com/jcobayliss/TC3002B-M2/refs/heads/main/datasets/iris.csv")

# Separamos las variables independientes de la dependiente
X = iris.drop("Species", axis = 1)
y = iris["Species"]

# Dividimos los datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.60, stratify = y, random_state = 24)

# Creamos un modelo de clasificación usando un árbol de decisión
model = DecisionTreeClassifier(random_state = 42)

# Entrenamos el modelo usando los datos de entrenamiento
model.fit(X_train, y_train)

# Realizamos la predicción usando los datos de prueba
prediction = model.predict(X_test)

# Generamos la matriz de confusión
confusion_matrix(y_test, prediction)
# Out:
# array([[20,  0,  0],
#        [ 0, 16,  4],
#        [ 0,  0, 20]])

# %%
# Importamos los módulos necesarios
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Visualizamos el árbol de decisión generado
plt.figure(figsize=(10, 8))
plot_tree(
    model,
    feature_names = X.columns,
    class_names=[str(c) for c in model.classes_],
    filled = True,
    rounded = True,
    impurity = True,
    proportion = False,
    fontsize = 8
)
# Out:
# [Text(0.4, 0.9, 'PetalL <= 2.45\ngini = 0.667\nsamples = 90\nvalue = [30, 30, 30]\nclass = Setosa'),
#  Text(0.2, 0.7, 'gini = 0.0\nsamples = 30\nvalue = [30, 0, 0]\nclass = Setosa'),
#  Text(0.30000000000000004, 0.8, 'True  '),
#  Text(0.6, 0.7, 'PetalL <= 4.85\ngini = 0.5\nsamples = 60\nvalue = [0, 30, 30]\nclass = Versicolor'),
#  Text(0.5, 0.8, '  False'),
#  Text(0.4, 0.5, 'PetalW <= 1.65\ngini = 0.117\nsamples = 32\nvalue = [0, 30, 2]\nclass = Versicolor'),
#  Text(0.2, 0.3, 'gini = 0.0\nsamples = 29\nvalue = [0, 29, 0]\nclass = Versicolor'),
#  Text(0.6, 0.3, 'SepalW <= 3.0\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = Virginica'),
#  Text(0.4, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = Virginica'),
#  Text(0.8, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = Versicolor'),
#  Text(0.8, 0.5, 'gini = 0.0\nsamples = 28\nvalue = [0, 0, 28]\nclass = Virginica')]

# %% [markdown]
# ## Ejemplo III
#
# Una ventaja de los árboles de decisión es que no requieren que los datos cuantitativos se encuentren en rangos similares (los datos no requieren escalamiento). Este comportamiento puede observarse claramente en este ejemplo.

# %%
# Importamos los módulos necesarios
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# Leemos los datos que usaremos
iris =  pd.read_csv("https://raw.githubusercontent.com/jcobayliss/TC3002B-M2/refs/heads/main/datasets/distance.csv")

# Separamos las variables independientes de la dependiente
X = iris.drop("Output", axis = 1)
y = iris["Output"]

# Dividimos los datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.60, stratify = y, random_state = 54321)

# Creamos un modelo de clasificación usando un árbol de decisión
model = DecisionTreeClassifier(random_state = 42)

# Entrenamos el modelo usando los datos de entrenamiento
model.fit(X_train, y_train)

# Realizamos la predicción usando los datos de prueba
prediction = model.predict(X_test)

# Generamos la matriz de confusión
confusion_matrix(y_test, prediction)
# Out:
# array([[60,  3],
#        [ 0, 57]])

# %%
# Importamos los módulos necesarios
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Visualizamos el árbol de decisión generado
plt.figure(figsize=(4, 4))
plot_tree(
    model,
    feature_names = X.columns,
    class_names=[str(c) for c in model.classes_],
    filled = True,
    rounded = True,
    impurity = True,
    proportion = False,
    fontsize = 8
)
# Out:
# [Text(0.5, 0.75, 'X2 <= 0.495\ngini = 0.498\nsamples = 180\nvalue = [95, 85]\nclass = 0'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 95\nvalue = [95, 0]\nclass = 0'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 85\nvalue = [0, 85]\nclass = 1'),
#  Text(0.625, 0.5, '  False')]
